# %% [markdown]
# # cc-mini Notebook UI
#
# This notebook starts the widget-based `cc-mini` app inside Jupyter.

# %%
from tui.notebook import create_default_notebook_app

app = create_default_notebook_app()
app.display()
